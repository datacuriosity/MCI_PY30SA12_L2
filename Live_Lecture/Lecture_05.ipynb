# %% [markdown]
# ![](https://docs.microsoft.com/vi-vn/azure/architecture/data-science-process/media/lifecycle/tdsp-lifecycle2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Structured data
# - Unstructed data
# - Geometric data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cross validation / K-fold

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](https://static.javatpoint.com/tutorial/ai/images/types-of-artificial-intelligence2.png)

# %% [markdown]
# - Data drift
# - Model drift

# %% [markdown]
# - Compile-time
# - Run-time

# %% [markdown]
# - Compiler programming
# - Interpreter programming
